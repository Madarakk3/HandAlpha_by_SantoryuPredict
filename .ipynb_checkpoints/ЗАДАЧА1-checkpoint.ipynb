# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
import nltk 
import string
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from nltk.stem import SnowballStemmer 
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import LogisticRegression 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import precision_score,recall_score,precision_recall_curve 
from matplotlib import pyplot as plt
from sklearn.metrics import PrecisionRecallDisplay
import numpy as np
from sklearn.model_selection import GridSearchCV
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/elmansulejmanov/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/elmansulejmanov/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/elmansulejmanov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("./data/labeled.csv", sep=",")

# %%
df.shape
# Out:
# (14412, 2)

# %%
df.head(10)
# Out:
#                                              comment  toxic
# 0               Верблюдов-то за что? Дебилы, бл...\n    1.0
# 1  Хохлы, это отдушина затюканого россиянина, мол...    1.0
# 2                          Собаке - собачья смерть\n    1.0
# 3  Страницу обнови, дебил. Это тоже не оскорблени...    1.0
# 4  тебя не убедил 6-страничный пдф в том, что Скр...    1.0
# 5  Для каких стан является эталоном современная с...    1.0
# 6  В шапке были ссылки на инфу по текущему фильму...    0.0
# 7  УПАД Т! ТАМ НЕЛЬЗЯ СТРОИТЬ! ТЕХНОЛОГИЙ НЕТ! РА...    1.0
# 8                      Ебать тебя разносит, шизик.\n    1.0
# 9                          Обосрался, сиди обтекай\n    1.0

# %%
df["toxic"] = df["toxic"].apply(int)

# %%
df["toxic"].value_counts()
# Out:
# toxic
# 0    9586
# 1    4826
# Name: count, dtype: int64

# %%
for c in df[df["toxic"]==1]["comment"].head(5):
    print(c)
# Out:
# Верблюдов-то за что? Дебилы, бл...
#
# Хохлы, это отдушина затюканого россиянина, мол, вон, а у хохлов еще хуже. Если бы хохлов не было, кисель их бы придумал.
#
# Собаке - собачья смерть
#
# Страницу обнови, дебил. Это тоже не оскорбление, а доказанный факт - не-дебил про себя во множественном числе писать не будет. Или мы в тебя верим - это ты и твои воображаемые друзья?
#
# тебя не убедил 6-страничный пдф в том, что Скрипалей отравила Россия? Анализировать и думать пытаешься? Ватник что ли?)

# %%
train_df, test_df = train_test_split(df, test_size=500)

# %%
test_df.shape
# Out:
# (500, 2)

# %%
test_df["toxic"].value_counts()
# Out:
# toxic
# 0    327
# 1    173
# Name: count, dtype: int64

# %%
train_df["toxic"].value_counts()
# Out:
# toxic
# 0    9259
# 1    4653
# Name: count, dtype: int64

# %%
sentence_example = df.iloc[1] ["comment"]
tokens = word_tokenize(sentence_example, language="russian")
tokens_without_punctuation = [i for i in tokens if i not in string.punctuation]
russian_stop_words = stopwords.words("russian")
tokens_without_stop_words_and_punctuation = [i for i in tokens_without_punctuation if i not in russian_stop_words]
snowball = SnowballStemmer (language="russian")
stemmed_tokens = [snowball.stem(i) for i in tokens_without_stop_words_and_punctuation]

# %%
print(f"Исходный текст: {sentence_example}")
print("---------------")
print(f"Токены: {tokens}")
print("---------------")
print(f"Токены без пунктуации: {tokens_without_punctuation}")
print("---------------")
print(f"Токены без пунктуации и стоп слов: {tokens_without_stop_words_and_punctuation}")
print("--------------")
print(f"Токены после стемминга: {stemmed_tokens}")
print("---------------")
# Out:
# Исходный текст: Хохлы, это отдушина затюканого россиянина, мол, вон, а у хохлов еще хуже. Если бы хохлов не было, кисель их бы придумал.
#
# ---------------
# Токены: ['Хохлы', ',', 'это', 'отдушина', 'затюканого', 'россиянина', ',', 'мол', ',', 'вон', ',', 'а', 'у', 'хохлов', 'еще', 'хуже', '.', 'Если', 'бы', 'хохлов', 'не', 'было', ',', 'кисель', 'их', 'бы', 'придумал', '.']
# ---------------
# Токены без пунктуации: ['Хохлы', 'это', 'отдушина', 'затюканого', 'россиянина', 'мол', 'вон', 'а', 'у', 'хохлов', 'еще', 'хуже', 'Если', 'бы', 'хохлов', 'не', 'было', 'кисель', 'их', 'бы', 'придумал']
# ---------------
# Токены без пунктуации и стоп слов: ['Хохлы', 'это', 'отдушина', 'затюканого', 'россиянина', 'мол', 'вон', 'хохлов', 'хуже', 'Если', 'хохлов', 'кисель', 'придумал']
# --------------
# Токены после стемминга: ['хохл', 'эт', 'отдушин', 'затюкан', 'россиянин', 'мол', 'вон', 'хохл', 'хуж', 'есл', 'хохл', 'кисел', 'придума']
# ---------------

# %%
snowball = SnowballStemmer (language="russian")
russian_stop_words = stopwords.words("russian")

def tokenize_sentence(sentence: str, remove_stop_words: bool = True):
    tokens = word_tokenize(sentence, language="russian")
    tokens = [i for i in tokens if i not in string.punctuation]
    if remove_stop_words:
        tokens = [i for i in tokens if i not in russian_stop_words]
    tokens = [snowball.stem(i) for i in tokens]
    return tokens

# %%
tokenize_sentence(sentence_example)
# Out:
# ['хохл',
#  'эт',
#  'отдушин',
#  'затюкан',
#  'россиянин',
#  'мол',
#  'вон',
#  'хохл',
#  'хуж',
#  'есл',
#  'хохл',
#  'кисел',
#  'придума']

# %%
vectorizer = TfidfVectorizer(tokenizer=lambda x: tokenize_sentence(x, remove_stop_words=True))

# %%
features = vectorizer.fit_transform(train_df["comment"])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
model=LogisticRegression(random_state=0)

# %%
model.fit(features, train_df["toxic"])
# Out:
# LogisticRegression(random_state=0)

# %%
model.predict(features[0])
# Out:
# array([0])

# %%
train_df["comment"].iloc[0]
# Out:
# 'От всего имущества получается 5 8\n'

# %%
model_pipeline = Pipeline([
    ("vectorizer",TfidfVectorizer(tokenizer=lambda x: tokenize_sentence(x, remove_stop_words=True))),
    ("model",LogisticRegression(random_state=0))
]
)

# %%
model_pipeline.fit(train_df["comment"], train_df["toxic"])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(tokenizer=<function <lambda> at 0x165486c00>)),
#                 ('model', LogisticRegression(random_state=0))])

# %%
model_pipeline.predict(["смерт"])
# Out:
# array([1])

# %%
precision_score(y_true=test_df["toxic"], y_pred=model_pipeline.predict(test_df ["comment"] ))
# Out:
# 0.9112903225806451

# %%
recall_score(y_true=test_df["toxic"], y_pred=model_pipeline.predict(test_df ["comment"]))
# Out:
# 0.653179190751445

# %%
# Получаем precision, recall и пороги
precision,recall,thresholds = precision_recall_curve(y_true=test_df["toxic"], y_score=model_pipeline.predict_proba(test_df["comment"])[:, 1])

# %%
# Строим график Precision-Recall
display = PrecisionRecallDisplay(precision=precision, recall=recall)
display.plot()
plt.show()

# %%
np.where(prec > 0.95)
# Out:
# (array([409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421,
#         422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434,
#         435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447,
#         448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460,
#         461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473,
#         474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486,
#         487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499,
#         500]),)

# %%
thresholds[0]
# Out:
# 0.0060770670332311255

# %%
precision_score(y_true=test_df["toxic"], y_pred=model_pipeline.predict_proba(test_df ["comment"]) [:, 1] > thresholds [415] )
# Out:
# 0.9761904761904762

# %%
recall_score(y_true=test_df["toxic"], y_pred=model_pipeline.predict_proba(test_df ["comment"]) [:, 1] > thresholds [415] )
# Out:
# 0.47398843930635837

# %%
grid_pipeline = Pipeline([
    ("vectorizer", TfidfVectorizer(tokenizer=lambda x: tokenize_sentence(x, remove_stop_words=True))),
    ("model",
     GridSearchCV(
         LogisticRegression (random_state=0),
         param_grid={'C': [0.1, 1, 10.]},
         cv=3, 
         verbose=4
     )
    )
])

# %%
grid_pipeline.fit(train_df["comment"], train_df["toxic"])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 1/3] END .............................C=0.1;, score=0.686 total time=   0.1s
# [CV 2/3] END .............................C=0.1;, score=0.686 total time=   0.1s
# [CV 3/3] END .............................C=0.1;, score=0.688 total time=   0.1s
# [CV 1/3] END ...............................C=1;, score=0.841 total time=   0.1s
# [CV 2/3] END ...............................C=1;, score=0.831 total time=   0.1s
# [CV 3/3] END ...............................C=1;, score=0.838 total time=   0.1s
# [CV 1/3] END ............................C=10.0;, score=0.865 total time=   0.3s
# [CV 2/3] END ............................C=10.0;, score=0.863 total time=   0.2s
# ...

# %%
model_pipelineC = Pipeline([
    ("vectorizer",TfidfVectorizer(tokenizer=lambda x: tokenize_sentence(x, remove_stop_words=True))),
    ("model",LogisticRegression(random_state=0, C=10.))
]
)

# %%
model_pipelineC.fit(train_df["comment"], train_df["toxic"])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(tokenizer=<function <lambda> at 0x165e09760>)),
#                 ('model', LogisticRegression(C=10.0, random_state=0))])

# %%
prec_c_10,rec_c_10,thresholds_c_10  = precision_recall_curve(y_true=test_df["toxic"], y_score=model_pipelineC.predict_proba(test_df["comment"])[:, 1])

# %%
np.where(prec_c_10 > 0.95)
# Out:
# (array([404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416,
#         417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429,
#         430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442,
#         443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455,
#         456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468,
#         469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481,
#         482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494,
#         495, 496, 497, 498, 499, 500]),)

# %%
precision_score(y_true=test_df["toxic"], y_pred=model_pipelineC.predict_proba(test_df ["comment"]) [:, 1] > thresholds_c_10 [397] )
# Out:
# 0.9215686274509803

# %%
recall_score(y_true=test_df["toxic"], y_pred=model_pipelineC.predict_proba(test_df ["comment"]) [:, 1] > thresholds_c_10 [397] )
# Out:
# 0.5433526011560693

# %%
display = PrecisionRecallDisplay(precision=precision,recall=recall)
display.plot()
plt.show()
