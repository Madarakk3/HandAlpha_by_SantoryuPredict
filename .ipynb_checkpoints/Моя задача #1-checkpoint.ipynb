# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import LogisticRegression 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import precision_score,recall_score,precision_recall_curve 
from sklearn.metrics import PrecisionRecallDisplay
import seaborn as sns

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df["Успеваемость по математике"]= df["math score"]>=70

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df["Успеваемость по математике"]= df["math score"]>=70
df.groupby("Успеваемость по математике")["gender"].value_counts()
df.groupby("Успеваемость по математике")["lunch"].value_counts()
df.groupby("Успеваемость по математике")["test preparation course"].value_counts()

fig,axes = plt.subplots(nrows = 3,ncols = 2,figsize=(14,12))
(ax1,ax2),(ax3,ax4),(ax5)=axes

genderdiff = ["MaleTrue","MaleFalse","FemaleTrue","FemaleFalse"]
genderdiffscore = [231,251,178,340]
colors = ["Yellow","Blue","Green","Purple"]
ax1.pie(genderdiffscore,labels = genderdiff,colors = colors,autopct = "%1.1f%%",startangle = 180,explode = [0.0,0.0,0.0,0.1])
ax1.set_title("Гендерная разница")

lunchdiff = ["StandardTrue","FreeTrue","StandardFalse","FreeFalse"]
lunchdiffscore = [322,87,323,268]
colors = ["Yellow","Blue","Green","Purple"]
ax2.pie(lunchdiffscore,labels = lunchdiff,colors = colors,autopct = "%1.1f%%",startangle = 90,explode = [0.1,0.0,0.0,0.0])
ax2.set_title("Разница в Ланчах")

coursediff = ["NoneTrue","NoneFalse","CompletedTrue","CompletedFalse"]
coursediffscore = [233,409,176,182]
colors = ["Yellow","Blue","Green","Purple"]
ax3.pie(coursediffscore,labels = coursediff,colors = colors,autopct = "%1.1f%%",startangle = 0,explode = [0.0,0.1,0.0,0.0])
ax3.set_title("Разница в Курсах")


sns.boxplot(data = df[["Успеваемость по математике","reading score","writing score"]], ax = ax4)
ax4.set_title("Сравнение")
# Out:
# Text(0.5, 1.0, 'Сравнение')

# %%
df.groupby("Успеваемость по математике")["reading score"].value_counts()
# Out:
# Успеваемость по математике  reading score
# False                       58               27
#                             64               25
#                             61               23
#                             72               23
#                             67               21
#                                              ..
# True                        65                2
#                             49                1
#                             55                1
#                             58                1
#                             61                1
# Name: count, Length: 106, dtype: int64
